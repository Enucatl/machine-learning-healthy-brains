# %%
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %%
df = pd.DataFrame.from_csv("../data/frontal_thickness-matteo-1479386566_medians.csv")
print(df)
# Out:
#      central  cerebellum  frontal  health
# 0          4           6        4       1
# 1          4           7        4       1
# 2          4           6        4       1
# 3          3           4        3       1
# 4          4           6        4       1
# 5          3           6        3       1
# 6          3           5        3       1
# 7          4           7        3       1
# 8          3           5        3       0
# 9          4           6        3       1
# 10         4           6        4       1
# 11         4           6        3       1
# 12         4           7        4       1
# 13         3           5        3       0
# 14         4           6        4       1
# 15         3           5        3       0
# 16         4           5        4       0
# 17         3           5        3       0
# 18         4           6        3       1
# 19         4           7        4       1
# 20         4           7        4       1
# 21         4           7        3       1
# 22         4           7        4       1
# 23         4           6        3       1
# 24         4           7        4       1
# 25         4           7        4       1
# 26         4           7        4       1
# 27         3           4        3       0
# 28         4           7        3       1
# 29         4           7        4       1
# ..       ...         ...      ...     ...
# 248        4           7        4       1
# 249        3           4        3       0
# 250        4           6        4       1
# 251        3           6        3       1
# 252        4           8        4       1
# 253        4           5        4       1
# 254        4           7        4       1
# 255        3           5        3       0
# 256        4           6        3       0
# 257        3           4        3       0
# 258        4           7        3       1
# 259        4           7        4       1
# 260        3           4        3       0
# 261        3           5        3       0
# 262        4           6        4       1
# 263        4           7        4       1
# 264        4           7        4       1
# 265        4           6        3       0
# 266        4           7        4       0
# 267        4           7        4       1
# 268        4           7        4       1
# 269        4           7        4       1
# 270        4           6        4       1
# 271        4           7        4       1
# 272        4           7        4       1
# 273        4           6        4       1
# 274        4           6        3       1
# 275        4           7        4       1
# 276        4           7        4       1
# 277        4           7        4       1
#
# [278 rows x 4 columns]

# %%
g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3)
# Out:
# /home/matteo/.pyenv/versions/2.7.12/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
